# %%
apps = {
    "google_pay": "com.google.android.apps.nbu.paisa.user",
    "paypal": "com.paypal.android.p2pmobile",
    "revolut": "com.revolut.revolut"
}

# %%
from google_play_scraper import reviews, Sort
import pandas as pd

apps = {
    "google_pay": "com.google.android.apps.nbu.paisa.user",
    "paypal": "com.paypal.android.p2pmobile",
    "revolut": "com.revolut.revolut"
}

all_reviews = []

for bank, app_id in apps.items():
    result, _ = reviews(
        app_id,
        lang="en",
        country="us",
        sort=Sort.NEWEST,
        count=500
    )

    for r in result:
        all_reviews.append({
            "review": r["content"],
            "rating": r["score"],
            "date": r["at"].date().isoformat(),
            "bank": bank,
            "source": "Google Play"
        })

df = pd.DataFrame(all_reviews)

print(df.shape)
df.head()
# Out:
# (1500, 5)
#                          review  rating        date        bank       source
# 0                          good       5  2026-05-15  google_pay  Google Play
# 1                          good       5  2026-05-15  google_pay  Google Play
# 2  real apk.in google pay the👍👍       5  2026-05-15  google_pay  Google Play
# 3                app vary naice       5  2026-05-15  google_pay  Google Play
# 4                          good       5  2026-05-15  google_pay  Google Play

# %%
df = df.drop_duplicates(subset=["review"])
df = df.dropna(subset=["review", "rating"])
df["date"] = pd.to_datetime(df["date"]).dt.strftime("%Y-%m-%d")
df = df[["review", "rating", "date", "bank", "source"]]

# %%
df.to_csv("data/clean_reviews.csv", index=False)
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 df.to_csv("data/clean_reviews.csv", index=False)
#
# File c:\Users\Kenen\Desktop\fintech-review-analytics\venv\Lib\site-packages\pandas\core\generic.py:3988, in NDFrame.to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, lineterminator, chunksize, date_format, doublequote, escapechar, decimal, errors, storage_options)
#    3984             float_format=float_format,
#    3985             decimal=decimal,
#    3986         )
#    3987
# -> 3988         return DataFrameRenderer(formatter).to_csv(
#    3989             path_or_buf,
#    3990             lineterminator=lineterminator,
#    3991             sep=sep,
#
# ...

# %%
import os

os.makedirs("data", exist_ok=True)

# %%
df.to_csv("data/clean_reviews.csv", index=False)

# %%
import os

os.chdir("..")
print(os.getcwd())
# Out:
# c:\Users\Kenen\desktop\fintech-review-analytics

# %%
df.to_csv("data/raw/clean_reviews.csv", index=False)

# %%
import os
print(os.path.exists("data/clean_reviews.csv"))
# Out:
# False

# %%
import os
print(os.path.exists("data/raw/|clean_reviews.csv"))
# Out:
# False

# %%
import os
print(os.path.exists("data/raw/clean_reviews.csv"))
# Out:
# True

# %%
import os

os.makedirs("data/processed", exist_ok=True)

# %%
df.to_csv("data/processed/clean_reviews.csv", index=False)

# %%
df.to_csv("data/raw/raw_reviews.csv", index=False)

# %%
print(df.shape)
# Out:
# (1203, 5)

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

df = pd.read_csv("task2_final_output.csv")

plt.figure(figsize=(10,6))
sns.countplot(data=df, x='bank', hue='sentiment_label')

plt.title("Sentiment Distribution by Bank")
plt.xlabel("Bank")
plt.ylabel("Number of Reviews")
plt.legend(title="Sentiment")

plt.tight_layout()
plt.savefig("sentiment_distribution.png")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[2], line 5
#       1 import pandas as pd
#       2 import seaborn as sns
#       3 import matplotlib.pyplot as plt
#       4
# ----> 5 df = pd.read_csv("task2_final_output.csv")
#       6
#       7 plt.figure(figsize=(10,6))
#       8 sns.countplot(data=df, x='bank', hue='sentiment_label')
#
# ...

# %%
import os
os.chdir("..")
print(os.getcwd())
# Out:
# c:\Users\Kenen\Desktop\fintech-review-analytics
